# %% [markdown]
# ### 元组学习

# %%
tup1 = (1,2,3,4,5)
type(tup1)
tu0 = tup1[0]
print(tu0)
# Out:
# 1

# %%
#尝试修改元组，拼接操作
tup1 = (12, 34.56)
tup2 = ('abc', 'xyz')
 
tup3 = tup1 + tup2
# tup3 = tuo1 += tup2
print (tup3)

# %%
tupp1 = (1,2,3)
tupp2 = (3,4,5,6)
tupp3 = tupp1 + tupp2
print("tupp3：")
print(tupp3)
# Out:
# tupp3：
# (1, 2, 3, 3, 4, 5, 6)

# %%
tup4 = ('Hi!',) * 4
print(tup4)
# Out:
# ('Hi!', 'Hi!', 'Hi!', 'Hi!')

# %%
#迭代使用
for x in (1,2,3):
    print(x,end=" ")
# Out:
# 1 2 3
